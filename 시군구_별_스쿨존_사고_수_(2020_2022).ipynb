# %% [markdown]
# <a href="https://colab.research.google.com/github/0204hyoj/schoolAccident/blob/main/%EC%8B%9C%EA%B5%B0%EA%B5%AC_%EB%B3%84_%EC%8A%A4%EC%BF%A8%EC%A1%B4_%EC%82%AC%EA%B3%A0_%EC%88%98_(2020_2022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
강원 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/강원.csv'
경기 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/경기.csv'
경남 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/경남.csv'
경북 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/경북.csv'
광주 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/광주.csv'
대구 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/대구.csv'
대전 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/대전.csv'
부산 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/부산.csv'
서울 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/서울.csv'
세종 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/세종.csv'
울산 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/울산.csv'
인천 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/인천.csv'
전남 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/전남.csv'
전북 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/전북.csv'
제주 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/제주.csv'
충남 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/충남.csv'
충북 = '/content/drive/MyDrive/데이터시각화/학교안전사고 경진대회/스쿨존 내 어린이 사고 데이터/충북.csv'

# %%
강원df = pd.read_csv(강원)
경기df = pd.read_csv(경기)
경남df = pd.read_csv(경남)
경북df = pd.read_csv(경북)
광주df = pd.read_csv(광주)
대구df = pd.read_csv(대구)
대전df = pd.read_csv(대전)
부산df = pd.read_csv(부산)
서울df = pd.read_csv(서울)
세종df = pd.read_csv(세종)
울산df = pd.read_csv(울산)
인천df = pd.read_csv(인천)
전남df = pd.read_csv(전남)
전북df = pd.read_csv(전북)
제주df = pd.read_csv(제주)
충남df = pd.read_csv(충남)
충북df = pd.read_csv(충북)

# %%
서울df['구'] = 서울df['시군구'].apply(lambda x: x.split(' ')[1])
서울result = 서울df.groupby(['구']).size().reset_index(name='사고수')

부산df['구'] = 부산df['시군구'].apply(lambda x: x.split(' ')[1])
부산result = 부산df.groupby(['구']).size().reset_index(name='사고수')

대구df['구'] = 대구df['시군구'].apply(lambda x: x.split(' ')[1])
대구result = 대구df.groupby(['구']).size().reset_index(name='사고수')

인천df['군/구'] = 인천df['시군구'].apply(lambda x: x.split(' ')[1])
인천result = 인천df.groupby(['군/구']).size().reset_index(name='사고수')

광주df['구'] = 광주df['시군구'].apply(lambda x: x.split(' ')[1])
광주result = 광주df.groupby(['구']).size().reset_index(name='사고수')

대전df['구'] = 대전df['시군구'].apply(lambda x: x.split(' ')[1])
대전result = 대전df.groupby(['구']).size().reset_index(name='사고수')

울산df['구'] = 울산df['시군구'].apply(lambda x: x.split(' ')[1])
울산result = 울산df.groupby(['구']).size().reset_index(name='사고수')

세종df['시'] = 세종df['시군구'].apply(lambda x: x.split(' ')[0])
세종result = 세종df.groupby(['시']).size().reset_index(name='사고수')

경기df['시/군/구'] = 경기df['시군구'].apply(lambda x: x.split(' ')[1])
경기result = 경기df.groupby(['시/군/구']).size().reset_index(name='사고수')

강원df['시/군'] = 강원df['시군구'].apply(lambda x: x.split(' ')[1])
강원result = 강원df.groupby(['시/군']).size().reset_index(name='사고수')

충북df['시/군'] = 충북df['시군구'].apply(lambda x: x.split(' ')[1])
충북result = 충북df.groupby(['시/군']).size().reset_index(name='사고수')

충남df['시/군'] = 충남df['시군구'].apply(lambda x: x.split(' ')[1])
충남result = 충남df.groupby(['시/군']).size().reset_index(name='사고수')

전북df['시/군'] = 전북df['시군구'].apply(lambda x: x.split(' ')[1])
전북result = 전북df.groupby(['시/군']).size().reset_index(name='사고수')

전남df['시/군'] = 전남df['시군구'].apply(lambda x: x.split(' ')[1])
전남result = 전남df.groupby(['시/군']).size().reset_index(name='사고수')

경북df['시/군'] = 경북df['시군구'].apply(lambda x: x.split(' ')[1])
경북result = 경북df.groupby(['시/군']).size().reset_index(name='사고수')

경남df['시/군'] = 경남df['시군구'].apply(lambda x: x.split(' ')[1])
경남result = 경남df.groupby(['시/군']).size().reset_index(name='사고수')

제주df['시'] = 제주df['시군구'].apply(lambda x: x.split(' ')[1])
제주result = 제주df.groupby(['시']).size().reset_index(name='사고수')

# %%
#서울
서울_result = 서울result.sort_values(by='사고수', ascending=False)
서울_result
# Out:
#        구  사고수
# 3    강서구   19
# 0    강남구   16
# 18   양천구   15
# 6    구로구   12
# 5    광진구   11
# 10  동대문구   11
# 17   송파구   11
# 19  영등포구   10
# 2    강북구    9
# 21   은평구    9
# 8    노원구    9
# 1    강동구    9
# 16   성북구    8
# 4    관악구    7
# 13  서대문구    7
# 15   성동구    7
# 24   중랑구    6
# 14   서초구    6
# 20   용산구    5
# 12   마포구    5
# 9    도봉구    4
# 7    금천구    4
# 23    중구    4
# 11   동작구    3
# 22   종로구    3

# %%
#부산
부산_result = 부산result.sort_values(by='사고수', ascending=False)
부산_result
# Out:
#        구  사고수
# 15  해운대구   15
# 1    금정구   12
# 9    사하구   12
# 5    동래구   11
# 6   부산진구   11
# 12   연제구   10
# 3     남구    9
# 7     북구    9
# 11   수영구    9
# 2    기장군    7
# 13   영도구    7
# 0    강서구    6
# 8    사상구    6
# 10    서구    5
# 4     동구    4
# 14    중구    1

# %%
#대구 달서구50
대구_result = 대구result.sort_values(by='사고수', ascending=False)
대구_result
# Out:
#      구  사고수
# 1  달서구   50
# 4   북구   11
# 6  수성구   11
# 3   동구    9
# 0   남구    6
# 2  달성군    6
# 5   서구    2
# 7   중구    1

# %%
#인천 서구34
인천_result = 인천result.sort_values(by='사고수', ascending=False)
인천_result
# Out:
#     군/구  사고수
# 6    서구   34
# 2   남동구   23
# 5   부평구   19
# 7   연수구   15
# 1   계양구    8
# 4  미추홀구    7
# 8    중구    7
# 0   강화군    1
# 3    동구    1

# %%
#광주
광주_result = 광주result.sort_values(by='사고수', ascending=False)
광주_result
# Out:
#      구  사고수
# 0  광산구   16
# 2   북구   16
# 3   서구   14
# 1   남구    7

# %%
#대전
대전_result = 대전result.sort_values(by='사고수', ascending=False)
대전_result
# Out:
#      구  사고수
# 3  유성구   20
# 2   서구   18
# 4   중구   16
# 1   동구    6
# 0  대덕구    4

# %%
#울산
울산_result = 울산result.sort_values(by='사고수', ascending=False)
울산_result
# Out:
#      구  사고수
# 2   북구   14
# 0   남구   10
# 4   중구    6
# 3  울주군    4
# 1   동구    2

# %%
#세종
세종_result = 세종result.sort_values(by='사고수', ascending=False)
세종_result
# Out:
#          시  사고수
# 0  세종특별자치시   17

# %%
#경기 안산41, 수원35, 화성32
경기_result = 경기result.sort_values(by='사고수', ascending=False)
경기_result
# Out:
#    시/군/구  사고수
# 13   안산시   41
# 11   수원시   35
# 26   화성시   32
# 7   남양주시   26
# 18   용인시   24
# 10   성남시   24
# 0    고양시   20
# 12   시흥시   20
# 9    부천시   20
# 23   평택시   15
# 22   파주시   14
# 3    광주시   13
# 6    김포시   13
# 20  의정부시   12
# 15   안양시   11
# 2    광명시    8
# 17   오산시    6
# 21   이천시    6
# 5    군포시    5
# 4    구리시    4
# 24   포천시    4
# 16   양주시    3
# 25   하남시    3
# 14   안성시    2
# 8   동두천시    2
# 1    과천시    1
# 19   의왕시    1

# %%
#강원
강원_result = 강원result.sort_values(by='사고수', ascending=False)
강원_result
# Out:
#    시/군  사고수
# 2  원주시   10
# 0  강릉시    5
# 4  춘천시    5
# 1  동해시    2
# 6  횡성군    2
# 3  인제군    1
# 5  태백시    1

# %%
#충북 청주39
충북_result = 충북result.sort_values(by='사고수', ascending=False)
충북_result
# Out:
#    시/군  사고수
# 8  청주시   39
# 9  충주시    8
# 5  제천시    6
# 4  음성군    3
# 7  진천군    3
# 0  괴산군    2
# 1  단양군    1
# 2  영동군    1
# 3  옥천군    1
# 6  증평군    1

# %%
#충남
충남_result = 충남result.sort_values(by='사고수', ascending=False)
충남_result
# Out:
#     시/군  사고수
# 11  천안시   23
# 1   공주시    6
# 9   아산시    6
# 4   당진시    5
# 3   논산시    3
# 8   서천군    3
# 6   부여군    2
# 7   서산시    2
# 0   계룡시    1
# 2   금산군    1
# 5   보령시    1
# 10  예산군    1
# 12  청양군    1
# 13  홍성군    1

# %%
#전북
전북_result = 전북result.sort_values(by='사고수', ascending=False)
전북_result
# Out:
#    시/군  사고수
# 6  전주시   24
# 4  익산시    6
# 0  군산시    4
# 3  완주군    2
# 7  정읍시    2
# 1  남원시    1
# 2  부안군    1
# 5  장수군    1

# %%
#전남
전남_result = 전남result.sort_values(by='사고수', ascending=False)
전남_result
# Out:
#     시/군  사고수
# 4   목포시    7
# 6   순천시    7
# 7   여수시    6
# 2   광양시    5
# 11  해남군    4
# 3   나주시    3
# 9   완도군    2
# 0   강진군    1
# 1   고흥군    1
# 5   보성군    1
# 8   영암군    1
# 10  장성군    1
# 12  화순군    1

# %%
#경북
경북_result = 경북result.sort_values(by='사고수', ascending=False)
경북_result
# Out:
#     시/군  사고수
# 2   구미시   24
# 1   경주시   12
# 0   경산시   11
# 16  포항시   11
# 7   안동시    6
# 4   김천시    5
# 6   상주시    4
# 15  칠곡군    3
# 5   봉화군    2
# 3   군위군    2
# 9   영주시    2
# 10  영천시    2
# 11  예천군    2
# 12  울진군    2
# 8   영덕군    2
# 13  의성군    1
# 14  청송군    1

# %%
#경남
경남_result = 경남result.sort_values(by='사고수', ascending=False)
경남_result
# Out:
#     시/군  사고수
# 8   창원시   19
# 2   김해시   16
# 5   양산시    7
# 6   진주시    7
# 9   통영시    7
# 0   거제시    6
# 3   사천시    5
# 10  함양군    4
# 1   거창군    3
# 4   산청군    1
# 7   창녕군    1
# 11  합천군    1

# %%
#제주
제주_result = 제주result.sort_values(by='사고수', ascending=False)
제주_result
# Out:
#       시  사고수
# 1   제주시   27
# 0  서귀포시    6
